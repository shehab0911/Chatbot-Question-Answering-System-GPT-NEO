# %% [markdown]
# <a href="https://colab.research.google.com/github/shehab0911/Chatbot-Question-Answering-Using-NLP/blob/main/HappyTrnasformer_train_complete_QA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat Apr  9 05:43:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
pip install happytransformer
# Out:
# ...
#      |████████████████████████████████| 45 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 8.9 MB/s
# ...
#      |████████████████████████████████| 325 kB 52.7 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 55.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 58.1 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 46.0 MB/s
# ...
#      |████████████████████████████████| 136 kB 55.3 MB/s
# ...
#      |████████████████████████████████| 127 kB 52.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 50.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 66.5 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 47.5 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 271 kB 52.8 MB/s
# ...
#      |████████████████████████████████| 144 kB 53.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from happytransformer import HappyGeneration

# %%
import os
import tensorflow as tf
from tensorflow import keras

# %%
happy_gen = HappyGeneration("GPT-NEO", "EleutherAI/gpt-neo-125M")
# Out:
# Downloading:   0%|          | 0.00/0.98k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/502M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]
# 04/09/2022 05:45:53 - INFO - happytransformer.happy_transformer -   Using model: cuda

# %%
from happytransformer import GENSettings
from happytransformer import GENTrainArgs

# %%
args = GENSettings(no_repeat_ngram_size=2)
args = GENTrainArgs(num_train_epochs=100)

# %%
#Approach 1
#happy_gen.train("/content/drive/MyDrive/Datasets/Body_text.txt",args)
#happy_gen.save('/content/drive/MyDrive/Datasets/my_model.h5')

# %%
happy_gen.train("/content/drive/MyDrive/Dataset/Body_text.txt",args)
# Out:
# 04/09/2022 05:46:45 - INFO - happytransformer.happy_transformer -   Preprocessing dataset...
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-2272c56161d295a5/0.0.0/4b86d314f7236db91f0a0f5cda32d4375445e64c5eda2692655dd99c2dac68e8. Subsequent calls will reuse this data.
# ...
#   0%|          | 0/33 [00:00<?, ?ba/s]
# 04/09/2022 05:46:55 - INFO - happytransformer.happy_transformer -   Training...
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 588
#   Num Epochs = 100
#   Instantaneous batch size per device = 1
# ...

# %%
result = happy_gen.generate_text("When COVID-19 was first reported?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result.text)
# Out:
#  It was earlier known as “the coronavirus disease 2019” or “COVID‐19”, which is a sore word, but it is also used by better known acts of violence, such as the Lasala Movement,

# %%
result = happy_gen.generate_text(" why Microarrays were used?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result)
# Out:
# GenerationResult(text='.. Interaction with Time of Sample Collection ::: ResultsIn the example shown in Figure 2, the red line shows 0.5% agarose g    student response to a simple question about thiolated lipid mediators :::')

# %%
print(result.text)
# Out:
# .. Interaction with Time of Sample Collection ::: ResultsIn the example shown in Figure 2, the red line shows 0.5% agarose g    student response to a simple question about thiolated lipid mediators :::

# %%
result = happy_gen.generate_text("what are the Comprehensive COVID-19 response with concomitant control?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result)
# Out:
# GenerationResult(text=' :::ekaiente University diarrhea ::: Repeat hospitalization and outcomesAfter the admission of patients with COVID-19 with      admitted to the ICU with a positive result for COVID-19 with sepsis-like')

# %%
print(result.text)
# Out:
#  :::ekaiente University diarrhea ::: Repeat hospitalization and outcomesAfter the admission of patients with COVID-19 with      admitted to the ICU with a positive result for COVID-19 with sepsis-like

# %%
result = happy_gen.generate_text("how countries are adjusted to COVID-19 ?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result)
# Out:
# GenerationResult(text='. Adjustment occurs when an individual is diagnosed with a disease or injury as well as experiencing a change in lifestyle, such as a change in air conditioning or heating, in accordance with a change in control parameter or the person’s exposure to the')

# %%
print(result.text)
# Out:
# . Adjustment occurs when an individual is diagnosed with a disease or injury as well as experiencing a change in lifestyle, such as a change in air conditioning or heating, in accordance with a change in control parameter or the person’s exposure to the

# %%
result=happy_gen.generate_text("what are the ratio of covid 19 death")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result)
# Out:
# GenerationResult(text=' to poverty rates?Relationsants with the low score (those who did not follow-up on them) indicate low income. The relations with the high score (those with the income above theanked) indicate the highest level of poverty.Relationsants with')

# %%
print(result.text)
# Out:
#  to poverty rates?Relationsants with the low score (those who did not follow-up on them) indicate low income. The relations with the high score (those with the income above theanked) indicate the highest level of poverty.Relationsants with

# %%
result=happy_gen.generate_text("what are the R0 of covid 19 ")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(result)
# Out:
# GenerationResult(text='  comparison, the R0 of covid 19   or R0 of a model with only two variables, is shown in Figure 6. It is worth noting that different models have distinct RSCs, as can be seen by the shapes of')

# %%
print(result.text)
# Out:
#   comparison, the R0 of covid 19   or R0 of a model with only two variables, is shown in Figure 6. It is worth noting that different models have distinct RSCs, as can be seen by the shapes of

# %%
# Recreate the exact same model, including its weights and the optimizer
new_model = tf.keras.models.load_model('/content/drive/MyDrive/my_model.h5')

# Show the model architecture
new_model.summary()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-48-99a3d252e9ac> in <module>()
#       1 # Recreate the exact same model, including its weights and the optimizer
# ----> 2 new_model = tf.keras.models.load_model('/content/drive/MyDrive/my_model.h5')
#       3
#       4 # Show the model architecture
#       5 new_model.summary()
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     114   else:
#     115     raise IOError(
# ...

# %%
print(result)
# Out:
# GenerationResult(text='  comparison, the R0 of covid 19   or R0 of a model with only two variables, is shown in Figure 6. It is worth noting that different models have distinct RSCs, as can be seen by the shapes of')

# %%
print(result.text)
# Out:
#   comparison, the R0 of covid 19   or R0 of a model with only two variables, is shown in Figure 6. It is worth noting that different models have distinct RSCs, as can be seen by the shapes of
